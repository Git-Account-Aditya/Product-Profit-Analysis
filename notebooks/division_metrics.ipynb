# %%
import numpy as np 
import pandas as pd  
from pathlib import Path 

CLEANED_DATAFRAME_LOCATION = Path(r'..\datasets\cleaned_dataset.csv')

cleaned_df = pd.read_csv(CLEANED_DATAFRAME_LOCATION)
cleaned_df.sample(2)
# Out:
#       Row ID                      Order ID  Order Date   Ship Date  \
# 9818    9819  US-2024-107384-CHO-TRI-54000  04-12-2025  31-05-2030
# 2516    2517  US-2022-113971-CHO-NUT-13000  08-05-2024  04-11-2027
#
#            Ship Mode  Customer ID Country/Region            City  \
# 9818  Standard Class       107384  United States       Rochester
# 2516  Standard Class       113971  United States  Cuyahoga Falls
#
#      State/Province Postal Code   Division    Region     Product ID  \
# 9818      Minnesota       55901  Chocolate  Interior  CHO-TRI-54000
# 2516           Ohio       44221  Chocolate  Atlantic  CHO-NUT-13000
#
#                            Product Name  Sales  Units  Gross Profit  Cost
# 9818  Wonka Bar - Triple Dazzle Caramel  18.75      5         12.25   6.5
# 2516  Wonka Bar - Nutty Crunch Surprise  20.94      6         14.94   6.0
